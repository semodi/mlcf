# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
siesta = pd.read_csv('../siesta/verlet_mc_results/verlet300_1000_5_500_keepv_dc.all.log', delim_whitespace=True, index_col = 0)

# %%
mbpol =  pd.read_csv('../siesta/verlet_mc_results/verlet300_1000_5_500_keepv_dc.mbpol.log', delim_whitespace=True, index_col = 0)

# %%
plot(mbpol['Epot[eV]'], siesta['Epot[eV]'], ls = '', marker = '.')

# %%
(mbpol['Epot[eV]'] - siesta['Epot[eV]']).std()/64
# Out:
# 0.0010890726035728947

# %%
(mbpol['Epot[eV]'] - siesta['Epot[eV]']).mean()
# Out:
# 3.5952866242038235

# %%
from ase import Atoms
from ase.io import read
from mbpol_calculator import MbpolCalculator

# %%
h2o = Atoms('64OHH',
            positions = read('../64.xyz').get_positions(),
            cell = [15, 15, 15],
            pbc = True)
h2o.calc = MbpolCalculator(h2o)

# %%
h2o_list = [Atoms(h2o) for i in range(4)]

# %%
h2o_list[2].set_pbc(False)

# %%
def f(x):
    return x, x+1 ,x+2

# %%
a,b,c = list(map(f,[2,3,4]))

# %%
a
# Out:
# (2, 3, 4)

# %%
list(map(f,[1]))
# Out:
# [(1, 2, 3)]

# %%
import numpy as np

# %%
np.where(np.array([1,2,3]) == 0)[0]
# Out:
# array([], dtype=int64)

# %%
np.argmin(np.array([0,-1,-2.2]))
# Out:
# 2
