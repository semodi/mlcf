# %%
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
system = 'monomers'
dpps = np.genfromtxt('./../data/DPPS/{}/energies.dat'.format(system))
bh = np.genfromtxt('./../data/BH/{}/energies.dat'.format(system))
mbpol = np.genfromtxt('./../data/MB-pol/{}/energies.mbp'.format(system))

# %%
np.std(dpps-mbpol)
# Out:
# 0.05384110827440679

# %%
np.std(bh-mbpol)
# Out:
# 0.056713484242794

# %%
plot(dpps, mbpol)

# %%
plot(bh, mbpol)

# %%
plot(bh- dpps)
